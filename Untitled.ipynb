# %%
import keras
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.applications.vgg16 import preprocess_input
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import Image
import pandas as pd

# %%
model2 = keras.models.load_model('model_vgg16_11.model')

# %%
def crop_image(image_path):
    im = Image.open(image_path)
    width, height = im.size
    if height < 400
    if height>width:
        left = int((width - ((1/3)*height))/2)
        right = int(((width - ((1/3)*height))/2) + ((1/3)*height))
        top = int((1/3)*height)
        bottom = int((2/3)*height)
    else:
        left = int((1/3)*width)
        right = int((2/3)*width)
        top = int((height - ((1/3)*width))/2)
        bottom = int(((height - ((1/3)*width))/2) + ((1/3)*width))
    cropped = im.crop((left, top, right, bottom))
    return (cropped)

# %%
tree = crop_image('./tree_pictures/dont_use_travis_photos/IMG_20180617_173344622_HDR.jpg').resize((224,224))

# %%
def make_prediction(image):
    image = img_to_array(image)
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    image = preprocess_input(image, mode='tf')
    yhat = model2.predict_classes(image)
    return(yhat)

# %%
types = ['Alder','Cedar','Douglas Fir','Fir','Maple','Oak','Pine']

# %%
def load_and_predict(image_path):
    tree = crop_image(image_path).resize((224,224))
    predict = make_prediction(tree)
    #print(predict[0])
    print (types[predict[0]], plt.imshow(tree));

# %%
load_and_predict('./tree_pictures/dont_use_travis_photos/IMG_20180617_185503088.jpg')
# Out:
# Pine AxesImage(54,36;334.8x217.44)

# %%
directory = './picts/'
df = pd.DataFrame()
for subdir, dirs, files in os.walk(directory):
    for file in files:
        if file.endswith('.DS_Store'):
            continue
        else:
            list1 = []
            image = load_img(subdir+'/'+file, target_size=(224,224))
            image = img_to_array(image)
            image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
            image = preprocess_input(image, mode='tf')
            yhat = model2.predict_classes(image)
            a = file
            b = subdir
            list1.append((yhat,a,b))
            print(list1)
            df.append(list1)
            print(df.head()            #print(yhat, file, subdir)
# Out:
# [(array([5]), 'oak_leaves_300.jpg', './picts/oak')]
# [(array([5]), 'oak_leaves_466.jpg', './picts/oak')]
# [(array([5]), 'oak_leaves_102.jpg', './picts/oak')]
# [(array([5]), 'oak_leaves_116.jpg', './picts/oak')]
# [(array([5]), 'oak_leaves_96.jpg', './picts/oak')]
# [(array([6]), 'oak_leaves_69.jpg', './picts/oak')]
# [(array([5]), 'oak_leaves_327.jpeg', './picts/oak')]
# [(array([5]), 'oak_leaves_274.jpg', './picts/oak')]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-1ed8f833f609> in <module>()
#      11             image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
#      12             image = preprocess_input(image, mode='tf')
# ---> 13             yhat = model2.predict_classes(image)
#      14             a = file
#      15             b = subdir
#
# ...
